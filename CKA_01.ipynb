# %% [markdown]
# <a href="https://colab.research.google.com/github/Lilhxr/leaf_detect/blob/main/CKA_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/cassava-deit-swin/'
# Out:
# /content/drive/MyDrive/cassava-deit-swin

# %%
# !pip install --no-deps albumentations==1.0.0 # image argumentation
# !pip install timm # pytorch image models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: albumentations==1.0.0 in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: timm in /usr/local/lib/python3.7/dist-packages (0.5.4)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)

# %%
from albumentations.pytorch import ToTensorV2
from datetime import datetime
from pathlib import Path
from sklearn.metrics import confusion_matrix
from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
from torch.optim import Adam, AdamW 
from torch.optim.lr_scheduler import ExponentialLR 
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torch.utils.tensorboard.writer import SummaryWriter
from torchvision.models import resnet34, resnet50
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from tqdm.notebook import tqdm
from functools import partial
from typing import List, Dict
import warnings
from warnings import warn
warnings.filterwarnings('ignore')

import albumentations as A
import gc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import timm
import torch
import torch.nn as nn
import torch.utils.data as data
import torchvision.transforms as transforms
import random

# %load_ext tensorboard

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16
NUM_WORKERS = 1
NUM_CLASS = 5
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %%
class Transforms:
    def __init__(self, transforms: A.Compose):
        self.transforms = transforms

    def __call__(self, img, *args, **kwargs):
        return self.transforms(image=np.array(img))

# %%
valid_augs_compose = A.Compose([
    A.Resize(height=IMAGE_SIZE, width=IMAGE_SIZE, p=1.0),
    A.Normalize(
        mean=IMAGENET_DEFAULT_MEAN,
        std=IMAGENET_DEFAULT_STD),
    ToTensorV2(),
])

# %%
valid_augs = Transforms(valid_augs_compose)

# %%
class CustomizedDataset(Dataset):
     '''convert ImageFolder to torchvision Dataset'''

     def __init__(self, dataset):
         self.dataset = dataset
         self.classes = self.dataset.classes
         self.targets = self.dataset.targets

     def __getitem__(self, index):
         img, lb = self.dataset[index]
         return (img['image'], lb)
     
     def __len__(self):
         return len(self.dataset)

# %%
from mpl_toolkits import axes_grid1
import matplotlib.pyplot as plt

def add_colorbar(im, aspect=10, pad_fraction=0.5, **kwargs):
    """Add a vertical color bar to an image plot."""
    divider = axes_grid1.make_axes_locatable(im.axes)
    width = axes_grid1.axes_size.AxesY(im.axes, aspect=1./aspect)
    pad = axes_grid1.axes_size.Fraction(pad_fraction, width)
    current_ax = plt.gca()
    cax = divider.append_axes("right", size=width, pad=pad)
    plt.sca(current_ax)
    return im.axes.figure.colorbar(im, cax=cax, **kwargs)

# %%
class CKA:
    def __init__(self, model1: nn.Module,
                 model2: nn.Module,
                 model1_name: str = None,
                 model2_name: str = None,
                 model1_layers: List[str] = None,
                 model2_layers: List[str] = None,
                 device: str ='cpu'):
        """
        :param model1: (nn.Module) Neural Network 1
        :param model2: (nn.Module) Neural Network 2
        :param model1_name: (str) Name of model 1
        :param model2_name: (str) Name of model 2
        :param model1_layers: (List) List of layers to extract features from
        :param model2_layers: (List) List of layers to extract features from
        :param device: Device to run the model
        """

        self.model1 = model1
        self.model2 = model2
        self.device = device
        self.model1_info = {}
        self.model2_info = {}

        if model1_name is None:
            self.model1_info['Name'] = model1.__repr__().split('(')[0]
        else:
            self.model1_info['Name'] = model1_name

        if model2_name is None:
            self.model2_info['Name'] = model2.__repr__().split('(')[0]
        else:
            self.model2_info['Name'] = model2_name

        if self.model1_info['Name'] == self.model2_info['Name']:
            warn(f"Both model have identical names - {self.model2_info['Name']}. " \
                 "It may cause confusion when interpreting the results. " \
                 "Consider giving unique names to the models :)")

        self.model1_info['Layers'] = []
        self.model2_info['Layers'] = []

        self.model1_features = {}
        self.model2_features = {}

        if len(list(model1.modules())) > 150 and model1_layers is None:
            warn("Model 1 seems to have a lot of layers. " \
                 "Consider giving a list of layers whose features you are concerned with " \
                 "through the 'model1_layers' parameter. Your CPU/GPU will thank you :)")

        self.model1_layers = model1_layers

        if len(list(model2.modules())) > 150 and model2_layers is None:
            warn("Model 2 seems to have a lot of layers. " \
                 "Consider giving a list of layers whose features you are concerned with " \
                 "through the 'model2_layers' parameter. Your CPU/GPU will thank you :)")

        self.model2_layers = model2_layers

        self._insert_hooks()
        self.model1 = self.model1.to(self.device)
        self.model2 = self.model2.to(self.device)
        self.model1.eval()
        self.model2.eval()

    def _log_layer(self,
                   model: str,
                   name: str,
                   layer: nn.Module,
                   inp: torch.Tensor,
                   out: torch.Tensor):

        if model == "model1":
            self.model1_features[name] = out

        elif model == "model2":
            self.model2_features[name] = out

        else:
            raise RuntimeError("Unknown model name for _log_layer.")

    def _insert_hooks(self):
        # Model 1
        for name, layer in self.model1.named_modules():
            if self.model1_layers is not None:
                if name in self.model1_layers:
                    self.model1_info['Layers'] += [name]
                    layer.register_forward_hook(partial(self._log_layer, "model1", name))
            else:
                self.model1_info['Layers'] += [name]
                layer.register_forward_hook(partial(self._log_layer, "model1", name))

        # Model 2
        for name, layer in self.model2.named_modules():
            if self.model2_layers is not None:
                if name in self.model2_layers:
                    self.model2_info['Layers'] += [name]
                    layer.register_forward_hook(partial(self._log_layer, "model2", name))
            else:
                self.model2_info['Layers'] += [name]
                layer.register_forward_hook(partial(self._log_layer, "model2", name))

    def _HSIC(self, K, L):
        """
        Computes the unbiased estimate of HSIC metric.
        Reference: https://arxiv.org/pdf/2010.15327.pdf Eq (3)
        """
        N = K.shape[0]
        ones = torch.ones(N, 1).to(self.device)
        result = torch.trace(K @ L)
        result += ((ones.t() @ K @ ones @ ones.t() @ L @ ones) / ((N - 1) * (N - 2))).item()
        result -= ((ones.t() @ K @ L @ ones) * 2 / (N - 2)).item()
        return (1 / (N * (N - 3)) * result).item()

    def compare(self,
                dataloader1: DataLoader,
                dataloader2: DataLoader = None) -> None:
        """
        Computes the feature similarity between the models on the
        given datasets.
        :param dataloader1: (DataLoader)
        :param dataloader2: (DataLoader) If given, model 2 will run on this
                            dataset. (default = None)
        """

        if dataloader2 is None:
            warn("Dataloader for Model 2 is not given. Using the same dataloader for both models.")
            dataloader2 = dataloader1

        self.model1_info['Dataset'] = dataloader1.dataset.__repr__().split('\n')[0]
        self.model2_info['Dataset'] = dataloader2.dataset.__repr__().split('\n')[0]

        N = len(self.model1_layers) if self.model1_layers is not None else len(list(self.model1.modules()))
        M = len(self.model2_layers) if self.model2_layers is not None else len(list(self.model2.modules()))

        self.hsic_matrix = torch.zeros(N, M, 3)

        num_batches = min(len(dataloader1), len(dataloader2))

        for (x1, *_), (x2, *_) in tqdm(zip(dataloader1, dataloader2), desc="| Comparing features |", total=num_batches):

            self.model1_features = {}
            self.model2_features = {}
            _ = self.model1(x1.to(self.device))
            _ = self.model2(x2.to(self.device))

            for i, (name1, feat1) in enumerate(self.model1_features.items()):
                X = feat1.flatten(1)
                K = X @ X.t()
                K.fill_diagonal_(0.0)
                self.hsic_matrix[i, :, 0] += self._HSIC(K, K) / num_batches

                for j, (name2, feat2) in enumerate(self.model2_features.items()):
                    Y = feat2.flatten(1)
                    L = Y @ Y.t()
                    L.fill_diagonal_(0.0)
                    assert K.shape == L.shape, f"Feature shape mistach! {K.shape}, {L.shape}"

                    self.hsic_matrix[i, j, 1] += self._HSIC(K, L) / num_batches
                    self.hsic_matrix[i, j, 2] += self._HSIC(L, L) / num_batches

        self.hsic_matrix = self.hsic_matrix[:, :, 1] / (self.hsic_matrix[:, :, 0].sqrt() *
                                                        self.hsic_matrix[:, :, 2].sqrt())
        self.hsic_matrix = torch.nan_to_num(self.hsic_matrix)
        #assert not torch.isnan(self.hsic_matrix).any(), "HSIC computation resulted in NANs"

    def export(self) -> Dict:
        """
        Exports the CKA data along with the respective model layer names.
        :return:
        """
        return {
            "model1_name": self.model1_info['Name'],
            "model2_name": self.model2_info['Name'],
            "CKA": self.hsic_matrix,
            "model1_layers": self.model1_info['Layers'],
            "model2_layers": self.model2_info['Layers'],
            "dataset1_name": self.model1_info['Dataset'],
            "dataset2_name": self.model2_info['Dataset']
        }

    def plot_results(self,
                     save_path: str = None,
                     title: str = None):
        fig, ax = plt.subplots()
        im = ax.imshow(self.hsic_matrix, origin='lower', cmap='magma')
        ax.set_xlabel(f"Layers {self.model2_info['Name']}", fontsize=15)
        ax.set_ylabel(f"Layers {self.model1_info['Name']}", fontsize=15)

        if title is not None:
            ax.set_title(f"{title}", fontsize=18)
        else:
            ax.set_title(f"{self.model1_info['Name']} vs {self.model2_info['Name']}", fontsize=18)

        add_colorbar(im)
        plt.tight_layout()

        if save_path is not None:
            plt.savefig(save_path, dpi=300)

        plt.show()

# %%
timm.list_models(pretrained=True)

# %%
model1 = timm.create_model('swin_tiny_patch4_window7_224', pretrained=True, num_classes=5)

# %%
model2 = timm.create_model('vit_tiny_patch16_224', pretrained=True, num_classes=5)

# %%
model3 = timm.create_model('efficientnet_b0', pretrained=True, num_classes=5)

# %%
model4 = timm.create_model('resnet101', pretrained=True, num_classes=5)

# %%
def feature_dimension_extractor(model):

    feature_dimension = {}
    input = torch.randn(16, 3, 224, 224)

    def hook_fn(name, module, input, output):
        feature_dimension[name] = output.size()

    for name, layer in model.named_modules():
        # hook_fn(module, input, output)
        layer.register_forward_hook(partial(hook_fn, name))
    _ = model(input)

    return feature_dimension

# %%
feature_dimension_extractor(model1)
# Out:
# {'': torch.Size([16, 5]),
#  'avgpool': torch.Size([16, 768, 1]),
#  'head': torch.Size([16, 5]),
#  'layers': torch.Size([16, 49, 768]),
#  'layers.0': torch.Size([16, 784, 192]),
#  'layers.0.blocks.0': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.attn': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.0.attn.attn_drop': torch.Size([1024, 3, 49, 49]),
#  'layers.0.blocks.0.attn.proj': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.0.attn.proj_drop': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.0.attn.qkv': torch.Size([1024, 49, 288]),
#  'layers.0.blocks.0.attn.softmax': torch.Size([1024, 3, 49, 49]),
#  'layers.0.blocks.0.drop_path': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.mlp': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.mlp.act': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.0.mlp.drop1': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.0.mlp.drop2': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.mlp.fc1': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.0.mlp.fc2': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.norm1': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.0.norm2': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.attn': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.1.attn.attn_drop': torch.Size([1024, 3, 49, 49]),
#  'layers.0.blocks.1.attn.proj': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.1.attn.proj_drop': torch.Size([1024, 49, 96]),
#  'layers.0.blocks.1.attn.qkv': torch.Size([1024, 49, 288]),
#  'layers.0.blocks.1.attn.softmax': torch.Size([1024, 3, 49, 49]),
#  'layers.0.blocks.1.drop_path': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.mlp': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.mlp.act': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.1.mlp.drop1': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.1.mlp.drop2': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.mlp.fc1': torch.Size([16, 3136, 384]),
#  'layers.0.blocks.1.mlp.fc2': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.norm1': torch.Size([16, 3136, 96]),
#  'layers.0.blocks.1.norm2': torch.Size([16, 3136, 96]),
#  'layers.0.downsample': torch.Size([16, 784, 192]),
#  'layers.0.downsample.norm': torch.Size([16, 784, 384]),
#  'layers.0.downsample.reduction': torch.Size([16, 784, 192]),
#  'layers.1': torch.Size([16, 196, 384]),
#  'layers.1.blocks.0': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.attn': torch.Size([256, 49, 192]),
#  'layers.1.blocks.0.attn.attn_drop': torch.Size([256, 6, 49, 49]),
#  'layers.1.blocks.0.attn.proj': torch.Size([256, 49, 192]),
#  'layers.1.blocks.0.attn.proj_drop': torch.Size([256, 49, 192]),
#  'layers.1.blocks.0.attn.qkv': torch.Size([256, 49, 576]),
#  'layers.1.blocks.0.attn.softmax': torch.Size([256, 6, 49, 49]),
#  'layers.1.blocks.0.drop_path': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.mlp': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.mlp.act': torch.Size([16, 784, 768]),
#  'layers.1.blocks.0.mlp.drop1': torch.Size([16, 784, 768]),
#  'layers.1.blocks.0.mlp.drop2': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.mlp.fc1': torch.Size([16, 784, 768]),
#  'layers.1.blocks.0.mlp.fc2': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.norm1': torch.Size([16, 784, 192]),
#  'layers.1.blocks.0.norm2': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.attn': torch.Size([256, 49, 192]),
#  'layers.1.blocks.1.attn.attn_drop': torch.Size([256, 6, 49, 49]),
#  'layers.1.blocks.1.attn.proj': torch.Size([256, 49, 192]),
#  'layers.1.blocks.1.attn.proj_drop': torch.Size([256, 49, 192]),
#  'layers.1.blocks.1.attn.qkv': torch.Size([256, 49, 576]),
#  'layers.1.blocks.1.attn.softmax': torch.Size([256, 6, 49, 49]),
#  'layers.1.blocks.1.drop_path': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.mlp': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.mlp.act': torch.Size([16, 784, 768]),
#  'layers.1.blocks.1.mlp.drop1': torch.Size([16, 784, 768]),
#  'layers.1.blocks.1.mlp.drop2': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.mlp.fc1': torch.Size([16, 784, 768]),
#  'layers.1.blocks.1.mlp.fc2': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.norm1': torch.Size([16, 784, 192]),
#  'layers.1.blocks.1.norm2': torch.Size([16, 784, 192]),
#  'layers.1.downsample': torch.Size([16, 196, 384]),
#  'layers.1.downsample.norm': torch.Size([16, 196, 768]),
#  'layers.1.downsample.reduction': torch.Size([16, 196, 384]),
#  'layers.2': torch.Size([16, 49, 768]),
#  'layers.2.blocks.0': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.0.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.0.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.0.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.0.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.0.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.0.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.0.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.0.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.0.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.0.norm2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.1.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.1.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.1.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.1.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.1.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.1.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.1.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.1.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.1.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.1.norm2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.2.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.2.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.2.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.2.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.2.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.2.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.2.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.2.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.2.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.2.norm2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.3.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.3.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.3.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.3.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.3.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.3.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.3.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.3.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.3.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.3.norm2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.4.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.4.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.4.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.4.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.4.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.4.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.4.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.4.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.4.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.4.norm2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.attn': torch.Size([64, 49, 384]),
#  'layers.2.blocks.5.attn.attn_drop': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.5.attn.proj': torch.Size([64, 49, 384]),
#  'layers.2.blocks.5.attn.proj_drop': torch.Size([64, 49, 384]),
#  'layers.2.blocks.5.attn.qkv': torch.Size([64, 49, 1152]),
#  'layers.2.blocks.5.attn.softmax': torch.Size([64, 12, 49, 49]),
#  'layers.2.blocks.5.drop_path': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.mlp': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.mlp.act': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.5.mlp.drop1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.5.mlp.drop2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.mlp.fc1': torch.Size([16, 196, 1536]),
#  'layers.2.blocks.5.mlp.fc2': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.norm1': torch.Size([16, 196, 384]),
#  'layers.2.blocks.5.norm2': torch.Size([16, 196, 384]),
#  'layers.2.downsample': torch.Size([16, 49, 768]),
#  'layers.2.downsample.norm': torch.Size([16, 49, 1536]),
#  'layers.2.downsample.reduction': torch.Size([16, 49, 768]),
#  'layers.3': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.attn': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.attn.attn_drop': torch.Size([16, 24, 49, 49]),
#  'layers.3.blocks.0.attn.proj': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.attn.proj_drop': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.attn.qkv': torch.Size([16, 49, 2304]),
#  'layers.3.blocks.0.attn.softmax': torch.Size([16, 24, 49, 49]),
#  'layers.3.blocks.0.drop_path': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.mlp': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.mlp.act': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.0.mlp.drop1': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.0.mlp.drop2': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.mlp.fc1': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.0.mlp.fc2': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.norm1': torch.Size([16, 49, 768]),
#  'layers.3.blocks.0.norm2': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.attn': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.attn.attn_drop': torch.Size([16, 24, 49, 49]),
#  'layers.3.blocks.1.attn.proj': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.attn.proj_drop': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.attn.qkv': torch.Size([16, 49, 2304]),
#  'layers.3.blocks.1.attn.softmax': torch.Size([16, 24, 49, 49]),
#  'layers.3.blocks.1.drop_path': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.mlp': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.mlp.act': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.1.mlp.drop1': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.1.mlp.drop2': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.mlp.fc1': torch.Size([16, 49, 3072]),
#  'layers.3.blocks.1.mlp.fc2': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.norm1': torch.Size([16, 49, 768]),
#  'layers.3.blocks.1.norm2': torch.Size([16, 49, 768]),
#  'norm': torch.Size([16, 49, 768]),
#  'patch_embed': torch.Size([16, 3136, 96]),
#  'patch_embed.norm': torch.Size([16, 3136, 96]),
#  'patch_embed.proj': torch.Size([16, 96, 56, 56]),
#  'pos_drop': torch.Size([16, 3136, 96])}

# %%
feature_dimension_extractor(model2)
# Out:
# {'': torch.Size([16, 5]),
#  'blocks': torch.Size([16, 197, 192]),
#  'blocks.0': torch.Size([16, 197, 192]),
#  'blocks.0.attn': torch.Size([16, 197, 192]),
#  'blocks.0.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.0.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.0.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.0.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.0.drop_path': torch.Size([16, 197, 192]),
#  'blocks.0.mlp': torch.Size([16, 197, 192]),
#  'blocks.0.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.0.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.0.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.0.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.0.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.0.norm1': torch.Size([16, 197, 192]),
#  'blocks.0.norm2': torch.Size([16, 197, 192]),
#  'blocks.1': torch.Size([16, 197, 192]),
#  'blocks.1.attn': torch.Size([16, 197, 192]),
#  'blocks.1.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.1.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.1.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.1.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.1.drop_path': torch.Size([16, 197, 192]),
#  'blocks.1.mlp': torch.Size([16, 197, 192]),
#  'blocks.1.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.1.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.1.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.1.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.1.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.1.norm1': torch.Size([16, 197, 192]),
#  'blocks.1.norm2': torch.Size([16, 197, 192]),
#  'blocks.10': torch.Size([16, 197, 192]),
#  'blocks.10.attn': torch.Size([16, 197, 192]),
#  'blocks.10.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.10.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.10.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.10.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.10.drop_path': torch.Size([16, 197, 192]),
#  'blocks.10.mlp': torch.Size([16, 197, 192]),
#  'blocks.10.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.10.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.10.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.10.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.10.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.10.norm1': torch.Size([16, 197, 192]),
#  'blocks.10.norm2': torch.Size([16, 197, 192]),
#  'blocks.11': torch.Size([16, 197, 192]),
#  'blocks.11.attn': torch.Size([16, 197, 192]),
#  'blocks.11.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.11.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.11.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.11.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.11.drop_path': torch.Size([16, 197, 192]),
#  'blocks.11.mlp': torch.Size([16, 197, 192]),
#  'blocks.11.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.11.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.11.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.11.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.11.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.11.norm1': torch.Size([16, 197, 192]),
#  'blocks.11.norm2': torch.Size([16, 197, 192]),
#  'blocks.2': torch.Size([16, 197, 192]),
#  'blocks.2.attn': torch.Size([16, 197, 192]),
#  'blocks.2.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.2.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.2.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.2.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.2.drop_path': torch.Size([16, 197, 192]),
#  'blocks.2.mlp': torch.Size([16, 197, 192]),
#  'blocks.2.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.2.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.2.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.2.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.2.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.2.norm1': torch.Size([16, 197, 192]),
#  'blocks.2.norm2': torch.Size([16, 197, 192]),
#  'blocks.3': torch.Size([16, 197, 192]),
#  'blocks.3.attn': torch.Size([16, 197, 192]),
#  'blocks.3.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.3.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.3.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.3.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.3.drop_path': torch.Size([16, 197, 192]),
#  'blocks.3.mlp': torch.Size([16, 197, 192]),
#  'blocks.3.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.3.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.3.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.3.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.3.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.3.norm1': torch.Size([16, 197, 192]),
#  'blocks.3.norm2': torch.Size([16, 197, 192]),
#  'blocks.4': torch.Size([16, 197, 192]),
#  'blocks.4.attn': torch.Size([16, 197, 192]),
#  'blocks.4.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.4.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.4.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.4.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.4.drop_path': torch.Size([16, 197, 192]),
#  'blocks.4.mlp': torch.Size([16, 197, 192]),
#  'blocks.4.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.4.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.4.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.4.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.4.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.4.norm1': torch.Size([16, 197, 192]),
#  'blocks.4.norm2': torch.Size([16, 197, 192]),
#  'blocks.5': torch.Size([16, 197, 192]),
#  'blocks.5.attn': torch.Size([16, 197, 192]),
#  'blocks.5.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.5.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.5.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.5.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.5.drop_path': torch.Size([16, 197, 192]),
#  'blocks.5.mlp': torch.Size([16, 197, 192]),
#  'blocks.5.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.5.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.5.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.5.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.5.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.5.norm1': torch.Size([16, 197, 192]),
#  'blocks.5.norm2': torch.Size([16, 197, 192]),
#  'blocks.6': torch.Size([16, 197, 192]),
#  'blocks.6.attn': torch.Size([16, 197, 192]),
#  'blocks.6.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.6.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.6.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.6.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.6.drop_path': torch.Size([16, 197, 192]),
#  'blocks.6.mlp': torch.Size([16, 197, 192]),
#  'blocks.6.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.6.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.6.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.6.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.6.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.6.norm1': torch.Size([16, 197, 192]),
#  'blocks.6.norm2': torch.Size([16, 197, 192]),
#  'blocks.7': torch.Size([16, 197, 192]),
#  'blocks.7.attn': torch.Size([16, 197, 192]),
#  'blocks.7.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.7.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.7.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.7.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.7.drop_path': torch.Size([16, 197, 192]),
#  'blocks.7.mlp': torch.Size([16, 197, 192]),
#  'blocks.7.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.7.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.7.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.7.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.7.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.7.norm1': torch.Size([16, 197, 192]),
#  'blocks.7.norm2': torch.Size([16, 197, 192]),
#  'blocks.8': torch.Size([16, 197, 192]),
#  'blocks.8.attn': torch.Size([16, 197, 192]),
#  'blocks.8.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.8.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.8.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.8.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.8.drop_path': torch.Size([16, 197, 192]),
#  'blocks.8.mlp': torch.Size([16, 197, 192]),
#  'blocks.8.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.8.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.8.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.8.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.8.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.8.norm1': torch.Size([16, 197, 192]),
#  'blocks.8.norm2': torch.Size([16, 197, 192]),
#  'blocks.9': torch.Size([16, 197, 192]),
#  'blocks.9.attn': torch.Size([16, 197, 192]),
#  'blocks.9.attn.attn_drop': torch.Size([16, 3, 197, 197]),
#  'blocks.9.attn.proj': torch.Size([16, 197, 192]),
#  'blocks.9.attn.proj_drop': torch.Size([16, 197, 192]),
#  'blocks.9.attn.qkv': torch.Size([16, 197, 576]),
#  'blocks.9.drop_path': torch.Size([16, 197, 192]),
#  'blocks.9.mlp': torch.Size([16, 197, 192]),
#  'blocks.9.mlp.act': torch.Size([16, 197, 768]),
#  'blocks.9.mlp.drop1': torch.Size([16, 197, 768]),
#  'blocks.9.mlp.drop2': torch.Size([16, 197, 192]),
#  'blocks.9.mlp.fc1': torch.Size([16, 197, 768]),
#  'blocks.9.mlp.fc2': torch.Size([16, 197, 192]),
#  'blocks.9.norm1': torch.Size([16, 197, 192]),
#  'blocks.9.norm2': torch.Size([16, 197, 192]),
#  'head': torch.Size([16, 5]),
#  'norm': torch.Size([16, 197, 192]),
#  'patch_embed': torch.Size([16, 196, 192]),
#  'patch_embed.norm': torch.Size([16, 196, 192]),
#  'patch_embed.proj': torch.Size([16, 192, 14, 14]),
#  'pos_drop': torch.Size([16, 197, 192]),
#  'pre_logits': torch.Size([16, 192])}

# %%
feature_dimension_extractor(model3)
# Out:
# {'': torch.Size([16, 5]),
#  'act1': torch.Size([16, 32, 112, 112]),
#  'act2': torch.Size([16, 1280, 7, 7]),
#  'blocks': torch.Size([16, 320, 7, 7]),
#  'blocks.0': torch.Size([16, 16, 112, 112]),
#  'blocks.0.0': torch.Size([16, 16, 112, 112]),
#  'blocks.0.0.act1': torch.Size([16, 32, 112, 112]),
#  'blocks.0.0.act2': torch.Size([16, 16, 112, 112]),
#  'blocks.0.0.bn1': torch.Size([16, 32, 112, 112]),
#  'blocks.0.0.bn2': torch.Size([16, 16, 112, 112]),
#  'blocks.0.0.conv_dw': torch.Size([16, 32, 112, 112]),
#  'blocks.0.0.conv_pw': torch.Size([16, 16, 112, 112]),
#  'blocks.0.0.se': torch.Size([16, 32, 112, 112]),
#  'blocks.0.0.se.act1': torch.Size([16, 8, 1, 1]),
#  'blocks.0.0.se.conv_expand': torch.Size([16, 32, 1, 1]),
#  'blocks.0.0.se.conv_reduce': torch.Size([16, 8, 1, 1]),
#  'blocks.0.0.se.gate': torch.Size([16, 32, 1, 1]),
#  'blocks.1': torch.Size([16, 24, 56, 56]),
#  'blocks.1.0': torch.Size([16, 24, 56, 56]),
#  'blocks.1.0.act1': torch.Size([16, 96, 112, 112]),
#  'blocks.1.0.act2': torch.Size([16, 96, 56, 56]),
#  'blocks.1.0.bn1': torch.Size([16, 96, 112, 112]),
#  'blocks.1.0.bn2': torch.Size([16, 96, 56, 56]),
#  'blocks.1.0.bn3': torch.Size([16, 24, 56, 56]),
#  'blocks.1.0.conv_dw': torch.Size([16, 96, 56, 56]),
#  'blocks.1.0.conv_pw': torch.Size([16, 96, 112, 112]),
#  'blocks.1.0.conv_pwl': torch.Size([16, 24, 56, 56]),
#  'blocks.1.0.se': torch.Size([16, 96, 56, 56]),
#  'blocks.1.0.se.act1': torch.Size([16, 4, 1, 1]),
#  'blocks.1.0.se.conv_expand': torch.Size([16, 96, 1, 1]),
#  'blocks.1.0.se.conv_reduce': torch.Size([16, 4, 1, 1]),
#  'blocks.1.0.se.gate': torch.Size([16, 96, 1, 1]),
#  'blocks.1.1': torch.Size([16, 24, 56, 56]),
#  'blocks.1.1.act1': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.act2': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.bn1': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.bn2': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.bn3': torch.Size([16, 24, 56, 56]),
#  'blocks.1.1.conv_dw': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.conv_pw': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.conv_pwl': torch.Size([16, 24, 56, 56]),
#  'blocks.1.1.se': torch.Size([16, 144, 56, 56]),
#  'blocks.1.1.se.act1': torch.Size([16, 6, 1, 1]),
#  'blocks.1.1.se.conv_expand': torch.Size([16, 144, 1, 1]),
#  'blocks.1.1.se.conv_reduce': torch.Size([16, 6, 1, 1]),
#  'blocks.1.1.se.gate': torch.Size([16, 144, 1, 1]),
#  'blocks.2': torch.Size([16, 40, 28, 28]),
#  'blocks.2.0': torch.Size([16, 40, 28, 28]),
#  'blocks.2.0.act1': torch.Size([16, 144, 56, 56]),
#  'blocks.2.0.act2': torch.Size([16, 144, 28, 28]),
#  'blocks.2.0.bn1': torch.Size([16, 144, 56, 56]),
#  'blocks.2.0.bn2': torch.Size([16, 144, 28, 28]),
#  'blocks.2.0.bn3': torch.Size([16, 40, 28, 28]),
#  'blocks.2.0.conv_dw': torch.Size([16, 144, 28, 28]),
#  'blocks.2.0.conv_pw': torch.Size([16, 144, 56, 56]),
#  'blocks.2.0.conv_pwl': torch.Size([16, 40, 28, 28]),
#  'blocks.2.0.se': torch.Size([16, 144, 28, 28]),
#  'blocks.2.0.se.act1': torch.Size([16, 6, 1, 1]),
#  'blocks.2.0.se.conv_expand': torch.Size([16, 144, 1, 1]),
#  'blocks.2.0.se.conv_reduce': torch.Size([16, 6, 1, 1]),
#  'blocks.2.0.se.gate': torch.Size([16, 144, 1, 1]),
#  'blocks.2.1': torch.Size([16, 40, 28, 28]),
#  'blocks.2.1.act1': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.act2': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.bn1': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.bn2': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.bn3': torch.Size([16, 40, 28, 28]),
#  'blocks.2.1.conv_dw': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.conv_pw': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.conv_pwl': torch.Size([16, 40, 28, 28]),
#  'blocks.2.1.se': torch.Size([16, 240, 28, 28]),
#  'blocks.2.1.se.act1': torch.Size([16, 10, 1, 1]),
#  'blocks.2.1.se.conv_expand': torch.Size([16, 240, 1, 1]),
#  'blocks.2.1.se.conv_reduce': torch.Size([16, 10, 1, 1]),
#  'blocks.2.1.se.gate': torch.Size([16, 240, 1, 1]),
#  'blocks.3': torch.Size([16, 80, 14, 14]),
#  'blocks.3.0': torch.Size([16, 80, 14, 14]),
#  'blocks.3.0.act1': torch.Size([16, 240, 28, 28]),
#  'blocks.3.0.act2': torch.Size([16, 240, 14, 14]),
#  'blocks.3.0.bn1': torch.Size([16, 240, 28, 28]),
#  'blocks.3.0.bn2': torch.Size([16, 240, 14, 14]),
#  'blocks.3.0.bn3': torch.Size([16, 80, 14, 14]),
#  'blocks.3.0.conv_dw': torch.Size([16, 240, 14, 14]),
#  'blocks.3.0.conv_pw': torch.Size([16, 240, 28, 28]),
#  'blocks.3.0.conv_pwl': torch.Size([16, 80, 14, 14]),
#  'blocks.3.0.se': torch.Size([16, 240, 14, 14]),
#  'blocks.3.0.se.act1': torch.Size([16, 10, 1, 1]),
#  'blocks.3.0.se.conv_expand': torch.Size([16, 240, 1, 1]),
#  'blocks.3.0.se.conv_reduce': torch.Size([16, 10, 1, 1]),
#  'blocks.3.0.se.gate': torch.Size([16, 240, 1, 1]),
#  'blocks.3.1': torch.Size([16, 80, 14, 14]),
#  'blocks.3.1.act1': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.act2': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.bn1': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.bn2': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.bn3': torch.Size([16, 80, 14, 14]),
#  'blocks.3.1.conv_dw': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.conv_pw': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.conv_pwl': torch.Size([16, 80, 14, 14]),
#  'blocks.3.1.se': torch.Size([16, 480, 14, 14]),
#  'blocks.3.1.se.act1': torch.Size([16, 20, 1, 1]),
#  'blocks.3.1.se.conv_expand': torch.Size([16, 480, 1, 1]),
#  'blocks.3.1.se.conv_reduce': torch.Size([16, 20, 1, 1]),
#  'blocks.3.1.se.gate': torch.Size([16, 480, 1, 1]),
#  'blocks.3.2': torch.Size([16, 80, 14, 14]),
#  'blocks.3.2.act1': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.act2': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.bn1': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.bn2': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.bn3': torch.Size([16, 80, 14, 14]),
#  'blocks.3.2.conv_dw': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.conv_pw': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.conv_pwl': torch.Size([16, 80, 14, 14]),
#  'blocks.3.2.se': torch.Size([16, 480, 14, 14]),
#  'blocks.3.2.se.act1': torch.Size([16, 20, 1, 1]),
#  'blocks.3.2.se.conv_expand': torch.Size([16, 480, 1, 1]),
#  'blocks.3.2.se.conv_reduce': torch.Size([16, 20, 1, 1]),
#  'blocks.3.2.se.gate': torch.Size([16, 480, 1, 1]),
#  'blocks.4': torch.Size([16, 112, 14, 14]),
#  'blocks.4.0': torch.Size([16, 112, 14, 14]),
#  'blocks.4.0.act1': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.act2': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.bn1': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.bn2': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.bn3': torch.Size([16, 112, 14, 14]),
#  'blocks.4.0.conv_dw': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.conv_pw': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.conv_pwl': torch.Size([16, 112, 14, 14]),
#  'blocks.4.0.se': torch.Size([16, 480, 14, 14]),
#  'blocks.4.0.se.act1': torch.Size([16, 20, 1, 1]),
#  'blocks.4.0.se.conv_expand': torch.Size([16, 480, 1, 1]),
#  'blocks.4.0.se.conv_reduce': torch.Size([16, 20, 1, 1]),
#  'blocks.4.0.se.gate': torch.Size([16, 480, 1, 1]),
#  'blocks.4.1': torch.Size([16, 112, 14, 14]),
#  'blocks.4.1.act1': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.act2': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.bn1': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.bn2': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.bn3': torch.Size([16, 112, 14, 14]),
#  'blocks.4.1.conv_dw': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.conv_pw': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.conv_pwl': torch.Size([16, 112, 14, 14]),
#  'blocks.4.1.se': torch.Size([16, 672, 14, 14]),
#  'blocks.4.1.se.act1': torch.Size([16, 28, 1, 1]),
#  'blocks.4.1.se.conv_expand': torch.Size([16, 672, 1, 1]),
#  'blocks.4.1.se.conv_reduce': torch.Size([16, 28, 1, 1]),
#  'blocks.4.1.se.gate': torch.Size([16, 672, 1, 1]),
#  'blocks.4.2': torch.Size([16, 112, 14, 14]),
#  'blocks.4.2.act1': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.act2': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.bn1': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.bn2': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.bn3': torch.Size([16, 112, 14, 14]),
#  'blocks.4.2.conv_dw': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.conv_pw': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.conv_pwl': torch.Size([16, 112, 14, 14]),
#  'blocks.4.2.se': torch.Size([16, 672, 14, 14]),
#  'blocks.4.2.se.act1': torch.Size([16, 28, 1, 1]),
#  'blocks.4.2.se.conv_expand': torch.Size([16, 672, 1, 1]),
#  'blocks.4.2.se.conv_reduce': torch.Size([16, 28, 1, 1]),
#  'blocks.4.2.se.gate': torch.Size([16, 672, 1, 1]),
#  'blocks.5': torch.Size([16, 192, 7, 7]),
#  'blocks.5.0': torch.Size([16, 192, 7, 7]),
#  'blocks.5.0.act1': torch.Size([16, 672, 14, 14]),
#  'blocks.5.0.act2': torch.Size([16, 672, 7, 7]),
#  'blocks.5.0.bn1': torch.Size([16, 672, 14, 14]),
#  'blocks.5.0.bn2': torch.Size([16, 672, 7, 7]),
#  'blocks.5.0.bn3': torch.Size([16, 192, 7, 7]),
#  'blocks.5.0.conv_dw': torch.Size([16, 672, 7, 7]),
#  'blocks.5.0.conv_pw': torch.Size([16, 672, 14, 14]),
#  'blocks.5.0.conv_pwl': torch.Size([16, 192, 7, 7]),
#  'blocks.5.0.se': torch.Size([16, 672, 7, 7]),
#  'blocks.5.0.se.act1': torch.Size([16, 28, 1, 1]),
#  'blocks.5.0.se.conv_expand': torch.Size([16, 672, 1, 1]),
#  'blocks.5.0.se.conv_reduce': torch.Size([16, 28, 1, 1]),
#  'blocks.5.0.se.gate': torch.Size([16, 672, 1, 1]),
#  'blocks.5.1': torch.Size([16, 192, 7, 7]),
#  'blocks.5.1.act1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.act2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.bn1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.bn2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.bn3': torch.Size([16, 192, 7, 7]),
#  'blocks.5.1.conv_dw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.conv_pw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.conv_pwl': torch.Size([16, 192, 7, 7]),
#  'blocks.5.1.se': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.1.se.act1': torch.Size([16, 48, 1, 1]),
#  'blocks.5.1.se.conv_expand': torch.Size([16, 1152, 1, 1]),
#  'blocks.5.1.se.conv_reduce': torch.Size([16, 48, 1, 1]),
#  'blocks.5.1.se.gate': torch.Size([16, 1152, 1, 1]),
#  'blocks.5.2': torch.Size([16, 192, 7, 7]),
#  'blocks.5.2.act1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.act2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.bn1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.bn2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.bn3': torch.Size([16, 192, 7, 7]),
#  'blocks.5.2.conv_dw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.conv_pw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.conv_pwl': torch.Size([16, 192, 7, 7]),
#  'blocks.5.2.se': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.2.se.act1': torch.Size([16, 48, 1, 1]),
#  'blocks.5.2.se.conv_expand': torch.Size([16, 1152, 1, 1]),
#  'blocks.5.2.se.conv_reduce': torch.Size([16, 48, 1, 1]),
#  'blocks.5.2.se.gate': torch.Size([16, 1152, 1, 1]),
#  'blocks.5.3': torch.Size([16, 192, 7, 7]),
#  'blocks.5.3.act1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.act2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.bn1': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.bn2': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.bn3': torch.Size([16, 192, 7, 7]),
#  'blocks.5.3.conv_dw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.conv_pw': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.conv_pwl': torch.Size([16, 192, 7, 7]),
#  'blocks.5.3.se': torch.Size([16, 1152, 7, 7]),
#  'blocks.5.3.se.act1': torch.Size([16, 48, 1, 1]),
#  'blocks.5.3.se.conv_expand': torch.Size([16, 1152, 1, 1]),
#  'blocks.5.3.se.conv_reduce': torch.Size([16, 48, 1, 1]),
#  'blocks.5.3.se.gate': torch.Size([16, 1152, 1, 1]),
#  'blocks.6': torch.Size([16, 320, 7, 7]),
#  'blocks.6.0': torch.Size([16, 320, 7, 7]),
#  'blocks.6.0.act1': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.act2': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.bn1': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.bn2': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.bn3': torch.Size([16, 320, 7, 7]),
#  'blocks.6.0.conv_dw': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.conv_pw': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.conv_pwl': torch.Size([16, 320, 7, 7]),
#  'blocks.6.0.se': torch.Size([16, 1152, 7, 7]),
#  'blocks.6.0.se.act1': torch.Size([16, 48, 1, 1]),
#  'blocks.6.0.se.conv_expand': torch.Size([16, 1152, 1, 1]),
#  'blocks.6.0.se.conv_reduce': torch.Size([16, 48, 1, 1]),
#  'blocks.6.0.se.gate': torch.Size([16, 1152, 1, 1]),
#  'bn1': torch.Size([16, 32, 112, 112]),
#  'bn2': torch.Size([16, 1280, 7, 7]),
#  'classifier': torch.Size([16, 5]),
#  'conv_head': torch.Size([16, 1280, 7, 7]),
#  'conv_stem': torch.Size([16, 32, 112, 112]),
#  'global_pool': torch.Size([16, 1280]),
#  'global_pool.flatten': torch.Size([16, 1280]),
#  'global_pool.pool': torch.Size([16, 1280, 1, 1])}

# %%
feature_dimension_extractor(model4)
# Out:
# {'': torch.Size([16, 5]),
#  'act1': torch.Size([16, 64, 112, 112]),
#  'bn1': torch.Size([16, 64, 112, 112]),
#  'conv1': torch.Size([16, 64, 112, 112]),
#  'fc': torch.Size([16, 5]),
#  'global_pool': torch.Size([16, 2048]),
#  'global_pool.flatten': torch.Size([16, 2048]),
#  'global_pool.pool': torch.Size([16, 2048, 1, 1]),
#  'layer1': torch.Size([16, 256, 56, 56]),
#  'layer1.0': torch.Size([16, 256, 56, 56]),
#  'layer1.0.act1': torch.Size([16, 64, 56, 56]),
#  'layer1.0.act2': torch.Size([16, 64, 56, 56]),
#  'layer1.0.act3': torch.Size([16, 256, 56, 56]),
#  'layer1.0.bn1': torch.Size([16, 64, 56, 56]),
#  'layer1.0.bn2': torch.Size([16, 64, 56, 56]),
#  'layer1.0.bn3': torch.Size([16, 256, 56, 56]),
#  'layer1.0.conv1': torch.Size([16, 64, 56, 56]),
#  'layer1.0.conv2': torch.Size([16, 64, 56, 56]),
#  'layer1.0.conv3': torch.Size([16, 256, 56, 56]),
#  'layer1.0.downsample': torch.Size([16, 256, 56, 56]),
#  'layer1.0.downsample.0': torch.Size([16, 256, 56, 56]),
#  'layer1.0.downsample.1': torch.Size([16, 256, 56, 56]),
#  'layer1.1': torch.Size([16, 256, 56, 56]),
#  'layer1.1.act1': torch.Size([16, 64, 56, 56]),
#  'layer1.1.act2': torch.Size([16, 64, 56, 56]),
#  'layer1.1.act3': torch.Size([16, 256, 56, 56]),
#  'layer1.1.bn1': torch.Size([16, 64, 56, 56]),
#  'layer1.1.bn2': torch.Size([16, 64, 56, 56]),
#  'layer1.1.bn3': torch.Size([16, 256, 56, 56]),
#  'layer1.1.conv1': torch.Size([16, 64, 56, 56]),
#  'layer1.1.conv2': torch.Size([16, 64, 56, 56]),
#  'layer1.1.conv3': torch.Size([16, 256, 56, 56]),
#  'layer1.2': torch.Size([16, 256, 56, 56]),
#  'layer1.2.act1': torch.Size([16, 64, 56, 56]),
#  'layer1.2.act2': torch.Size([16, 64, 56, 56]),
#  'layer1.2.act3': torch.Size([16, 256, 56, 56]),
#  'layer1.2.bn1': torch.Size([16, 64, 56, 56]),
#  'layer1.2.bn2': torch.Size([16, 64, 56, 56]),
#  'layer1.2.bn3': torch.Size([16, 256, 56, 56]),
#  'layer1.2.conv1': torch.Size([16, 64, 56, 56]),
#  'layer1.2.conv2': torch.Size([16, 64, 56, 56]),
#  'layer1.2.conv3': torch.Size([16, 256, 56, 56]),
#  'layer2': torch.Size([16, 512, 28, 28]),
#  'layer2.0': torch.Size([16, 512, 28, 28]),
#  'layer2.0.act1': torch.Size([16, 128, 56, 56]),
#  'layer2.0.act2': torch.Size([16, 128, 28, 28]),
#  'layer2.0.act3': torch.Size([16, 512, 28, 28]),
#  'layer2.0.bn1': torch.Size([16, 128, 56, 56]),
#  'layer2.0.bn2': torch.Size([16, 128, 28, 28]),
#  'layer2.0.bn3': torch.Size([16, 512, 28, 28]),
#  'layer2.0.conv1': torch.Size([16, 128, 56, 56]),
#  'layer2.0.conv2': torch.Size([16, 128, 28, 28]),
#  'layer2.0.conv3': torch.Size([16, 512, 28, 28]),
#  'layer2.0.downsample': torch.Size([16, 512, 28, 28]),
#  'layer2.0.downsample.0': torch.Size([16, 512, 28, 28]),
#  'layer2.0.downsample.1': torch.Size([16, 512, 28, 28]),
#  'layer2.1': torch.Size([16, 512, 28, 28]),
#  'layer2.1.act1': torch.Size([16, 128, 28, 28]),
#  'layer2.1.act2': torch.Size([16, 128, 28, 28]),
#  'layer2.1.act3': torch.Size([16, 512, 28, 28]),
#  'layer2.1.bn1': torch.Size([16, 128, 28, 28]),
#  'layer2.1.bn2': torch.Size([16, 128, 28, 28]),
#  'layer2.1.bn3': torch.Size([16, 512, 28, 28]),
#  'layer2.1.conv1': torch.Size([16, 128, 28, 28]),
#  'layer2.1.conv2': torch.Size([16, 128, 28, 28]),
#  'layer2.1.conv3': torch.Size([16, 512, 28, 28]),
#  'layer2.2': torch.Size([16, 512, 28, 28]),
#  'layer2.2.act1': torch.Size([16, 128, 28, 28]),
#  'layer2.2.act2': torch.Size([16, 128, 28, 28]),
#  'layer2.2.act3': torch.Size([16, 512, 28, 28]),
#  'layer2.2.bn1': torch.Size([16, 128, 28, 28]),
#  'layer2.2.bn2': torch.Size([16, 128, 28, 28]),
#  'layer2.2.bn3': torch.Size([16, 512, 28, 28]),
#  'layer2.2.conv1': torch.Size([16, 128, 28, 28]),
#  'layer2.2.conv2': torch.Size([16, 128, 28, 28]),
#  'layer2.2.conv3': torch.Size([16, 512, 28, 28]),
#  'layer2.3': torch.Size([16, 512, 28, 28]),
#  'layer2.3.act1': torch.Size([16, 128, 28, 28]),
#  'layer2.3.act2': torch.Size([16, 128, 28, 28]),
#  'layer2.3.act3': torch.Size([16, 512, 28, 28]),
#  'layer2.3.bn1': torch.Size([16, 128, 28, 28]),
#  'layer2.3.bn2': torch.Size([16, 128, 28, 28]),
#  'layer2.3.bn3': torch.Size([16, 512, 28, 28]),
#  'layer2.3.conv1': torch.Size([16, 128, 28, 28]),
#  'layer2.3.conv2': torch.Size([16, 128, 28, 28]),
#  'layer2.3.conv3': torch.Size([16, 512, 28, 28]),
#  'layer3': torch.Size([16, 1024, 14, 14]),
#  'layer3.0': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.act1': torch.Size([16, 256, 28, 28]),
#  'layer3.0.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.0.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.bn1': torch.Size([16, 256, 28, 28]),
#  'layer3.0.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.0.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.conv1': torch.Size([16, 256, 28, 28]),
#  'layer3.0.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.0.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.downsample': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.downsample.0': torch.Size([16, 1024, 14, 14]),
#  'layer3.0.downsample.1': torch.Size([16, 1024, 14, 14]),
#  'layer3.1': torch.Size([16, 1024, 14, 14]),
#  'layer3.1.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.1.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.1.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.1.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.1.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.1.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.1.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.1.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.1.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.10': torch.Size([16, 1024, 14, 14]),
#  'layer3.10.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.10.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.10.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.10.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.10.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.10.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.10.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.10.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.10.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.11': torch.Size([16, 1024, 14, 14]),
#  'layer3.11.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.11.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.11.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.11.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.11.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.11.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.11.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.11.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.11.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.12': torch.Size([16, 1024, 14, 14]),
#  'layer3.12.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.12.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.12.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.12.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.12.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.12.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.12.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.12.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.12.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.13': torch.Size([16, 1024, 14, 14]),
#  'layer3.13.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.13.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.13.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.13.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.13.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.13.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.13.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.13.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.13.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.14': torch.Size([16, 1024, 14, 14]),
#  'layer3.14.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.14.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.14.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.14.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.14.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.14.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.14.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.14.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.14.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.15': torch.Size([16, 1024, 14, 14]),
#  'layer3.15.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.15.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.15.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.15.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.15.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.15.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.15.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.15.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.15.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.16': torch.Size([16, 1024, 14, 14]),
#  'layer3.16.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.16.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.16.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.16.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.16.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.16.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.16.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.16.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.16.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.17': torch.Size([16, 1024, 14, 14]),
#  'layer3.17.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.17.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.17.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.17.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.17.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.17.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.17.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.17.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.17.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.18': torch.Size([16, 1024, 14, 14]),
#  'layer3.18.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.18.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.18.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.18.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.18.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.18.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.18.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.18.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.18.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.19': torch.Size([16, 1024, 14, 14]),
#  'layer3.19.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.19.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.19.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.19.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.19.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.19.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.19.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.19.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.19.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.2': torch.Size([16, 1024, 14, 14]),
#  'layer3.2.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.2.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.2.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.2.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.2.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.2.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.2.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.2.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.2.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.20': torch.Size([16, 1024, 14, 14]),
#  'layer3.20.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.20.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.20.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.20.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.20.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.20.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.20.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.20.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.20.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.21': torch.Size([16, 1024, 14, 14]),
#  'layer3.21.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.21.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.21.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.21.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.21.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.21.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.21.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.21.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.21.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.22': torch.Size([16, 1024, 14, 14]),
#  'layer3.22.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.22.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.22.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.22.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.22.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.22.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.22.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.22.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.22.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.3': torch.Size([16, 1024, 14, 14]),
#  'layer3.3.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.3.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.3.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.3.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.3.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.3.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.3.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.3.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.3.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.4': torch.Size([16, 1024, 14, 14]),
#  'layer3.4.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.4.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.4.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.4.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.4.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.4.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.4.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.4.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.4.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.5': torch.Size([16, 1024, 14, 14]),
#  'layer3.5.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.5.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.5.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.5.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.5.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.5.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.5.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.5.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.5.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.6': torch.Size([16, 1024, 14, 14]),
#  'layer3.6.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.6.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.6.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.6.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.6.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.6.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.6.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.6.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.6.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.7': torch.Size([16, 1024, 14, 14]),
#  'layer3.7.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.7.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.7.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.7.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.7.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.7.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.7.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.7.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.7.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.8': torch.Size([16, 1024, 14, 14]),
#  'layer3.8.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.8.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.8.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.8.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.8.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.8.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.8.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.8.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.8.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer3.9': torch.Size([16, 1024, 14, 14]),
#  'layer3.9.act1': torch.Size([16, 256, 14, 14]),
#  'layer3.9.act2': torch.Size([16, 256, 14, 14]),
#  'layer3.9.act3': torch.Size([16, 1024, 14, 14]),
#  'layer3.9.bn1': torch.Size([16, 256, 14, 14]),
#  'layer3.9.bn2': torch.Size([16, 256, 14, 14]),
#  'layer3.9.bn3': torch.Size([16, 1024, 14, 14]),
#  'layer3.9.conv1': torch.Size([16, 256, 14, 14]),
#  'layer3.9.conv2': torch.Size([16, 256, 14, 14]),
#  'layer3.9.conv3': torch.Size([16, 1024, 14, 14]),
#  'layer4': torch.Size([16, 2048, 7, 7]),
#  'layer4.0': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.act1': torch.Size([16, 512, 14, 14]),
#  'layer4.0.act2': torch.Size([16, 512, 7, 7]),
#  'layer4.0.act3': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.bn1': torch.Size([16, 512, 14, 14]),
#  'layer4.0.bn2': torch.Size([16, 512, 7, 7]),
#  'layer4.0.bn3': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.conv1': torch.Size([16, 512, 14, 14]),
#  'layer4.0.conv2': torch.Size([16, 512, 7, 7]),
#  'layer4.0.conv3': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.downsample': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.downsample.0': torch.Size([16, 2048, 7, 7]),
#  'layer4.0.downsample.1': torch.Size([16, 2048, 7, 7]),
#  'layer4.1': torch.Size([16, 2048, 7, 7]),
#  'layer4.1.act1': torch.Size([16, 512, 7, 7]),
#  'layer4.1.act2': torch.Size([16, 512, 7, 7]),
#  'layer4.1.act3': torch.Size([16, 2048, 7, 7]),
#  'layer4.1.bn1': torch.Size([16, 512, 7, 7]),
#  'layer4.1.bn2': torch.Size([16, 512, 7, 7]),
#  'layer4.1.bn3': torch.Size([16, 2048, 7, 7]),
#  'layer4.1.conv1': torch.Size([16, 512, 7, 7]),
#  'layer4.1.conv2': torch.Size([16, 512, 7, 7]),
#  'layer4.1.conv3': torch.Size([16, 2048, 7, 7]),
#  'layer4.2': torch.Size([16, 2048, 7, 7]),
#  'layer4.2.act1': torch.Size([16, 512, 7, 7]),
#  'layer4.2.act2': torch.Size([16, 512, 7, 7]),
#  'layer4.2.act3': torch.Size([16, 2048, 7, 7]),
#  'layer4.2.bn1': torch.Size([16, 512, 7, 7]),
#  'layer4.2.bn2': torch.Size([16, 512, 7, 7]),
#  'layer4.2.bn3': torch.Size([16, 2048, 7, 7]),
#  'layer4.2.conv1': torch.Size([16, 512, 7, 7]),
#  'layer4.2.conv2': torch.Size([16, 512, 7, 7]),
#  'layer4.2.conv3': torch.Size([16, 2048, 7, 7]),
#  'maxpool': torch.Size([16, 64, 56, 56])}

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(0)
np.random.seed(0)
random.seed(0)

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])

test_data = CustomizedDataset(ImageFolder("data/cassavaleafdata/test", transform=valid_augs))
test_dataloader = DataLoader(test_data, 
                             batch_size=BATCH_SIZE, 
                             shuffle=False, 
                             num_workers=NUM_WORKERS,
                             worker_init_fn=seed_worker,
                             generator=g)

# %%
cka = CKA(model2, model3,
        model1_name="VIT-TINY", model2_name="EFFICI",
        device='cuda')

# %%
cka.compare(test_dataloader)
# Out:
# | Comparing features |:   0%|          | 0/118 [00:00<?, ?it/s]

# %%
cka.plot_results(save_path="./tiny-vit-eff-compare.png")
