# %% [markdown]
# <a href="https://colab.research.google.com/github/Lilhxr/leaf_detect/blob/main/R101_cassava_HSIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/dissertation_exprienments/visualizing-vision-models/visualizing-vision-models-main'
# Out:
# /content/drive/MyDrive/dissertation_exprienments/visualizing-vision-models/visualizing-vision-models-main

# %%
# !pip install --no-deps albumentations==1.0.0 # image argumentation
# !pip install timm # pytorch image models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting albumentations==1.0.0
#   Downloading albumentations-1.0.0-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.6 MB/s
# Installing collected packages: albumentations
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 0.1.12
#     Uninstalling albumentations-0.1.12:
#       Successfully uninstalled albumentations-0.1.12
# Successfully installed albumentations-1.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      |████████████████████████████████| 431 kB 4.2 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.12.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Installing collected packages: timm
# Successfully installed timm-0.5.4

# %%
from __future__ import print_function, division
from albumentations.pytorch import ToTensorV2
from datetime import datetime
from pathlib import Path
from sklearn.metrics import confusion_matrix
from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
from torch.optim import Adam, AdamW 
from torch.optim.lr_scheduler import ExponentialLR 
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torch.utils.tensorboard.writer import SummaryWriter
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

import albumentations as A
import gc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn
import timm
import torch
import torch.nn as nn
import torch.utils.data as data
import torchvision.transforms as transforms
import random

import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import sys

# %load_ext tensorboard

# %%
from pathlib import Path
sys.path.insert(0,os.path.abspath('./'))
sys.path.insert(0,os.path.abspath('./utilities'))

# %%
from utilities.resnet import resnet101

# %%
from utilities.utils import *

# %%
seed=566
torch.manual_seed(seed)
np.random.seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ## Resnet 101 on CIFAR-100

# %%
model = resnet101(num_classes=5, pretrained=True)

# %%
LABEL='R101-CIFAR100'
TYPE='PRETRAINED'

# %% [markdown]
# ## Getting the hooks for each layers

# %%
hookLayersActivationDict = {}
activationDict = {}

# %%
modelNamedModules = dict(model.named_modules())

# %%
hookLayers = []
for i in modelNamedModules.keys():
    if i.__contains__("bn") or i.__contains__("relu") or i.__contains__("avgpool") or i.__contains__("fc") or i.__contains__("maxpool") :
        hookLayers.append(i)

# %%
for layer in hookLayers:
    h = model.get_submodule(layer).register_forward_hook(getActivation(layer,hookLayersActivationDict))

# %% [markdown]
# ## CIFAR 100

# %%
IMAGE_SIZE = 224
TRAIN_BATCH_SIZE = 8
TEST_BATCH_SIZE = 8
NUM_WORKERS = 2
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")

class Transforms:
    def __init__(self, transforms: A.Compose):
        self.transforms = transforms

    def __call__(self, img, *args, **kwargs):
        return self.transforms(image=np.array(img))

train_augs_compose = A.Compose([
    A.RandomResizedCrop(height=IMAGE_SIZE, width=IMAGE_SIZE, p=1.0),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.5),
    A.ShiftScaleRotate(p=0.5),
    A.Normalize(    
        mean=IMAGENET_DEFAULT_MEAN,
        std=IMAGENET_DEFAULT_STD),
    A.CoarseDropout(p=0.5),
    ToTensorV2(),
])

valid_augs_compose = A.Compose([
    A.Resize(height=IMAGE_SIZE, width=IMAGE_SIZE, p=1.0),
    A.Normalize(
        mean=IMAGENET_DEFAULT_MEAN,
        std=IMAGENET_DEFAULT_STD),
    ToTensorV2(),
])

train_augs = Transforms(train_augs_compose)
valid_augs = Transforms(valid_augs_compose)
# Out:
# Device: cuda

# %%
class CustomizedDataset(Dataset):
     '''convert ImageFolder to torchvision Dataset'''

     def __init__(self, dataset):
         self.dataset = dataset
         self.classes = self.dataset.classes
         self.targets = self.dataset.targets

     def __getitem__(self, index):
         img, lb = self.dataset[index]
         return (img['image'], lb)
     
     def __len__(self):
         return len(self.dataset)

# %%
train_data = CustomizedDataset(ImageFolder("/content/drive/MyDrive/dissertation_exprienments/data/cassavaleafdata/train", transform=train_augs))

class_sample_counts = np.empty(len(train_data.classes), dtype=int)
for idx in range(len(train_data.classes)):
    class_sample_counts[idx] = train_data.targets.count(idx)

weights = 1. / torch.tensor(class_sample_counts, dtype=torch.float)
samples_weights = weights[train_data.targets]

# data balancer
sampler = data.WeightedRandomSampler(
    weights=samples_weights,
    num_samples=len(samples_weights),
    replacement=True)

train_loader = DataLoader(train_data, batch_size=TRAIN_BATCH_SIZE, sampler=sampler, num_workers=NUM_WORKERS)

# %%
validation_data = CustomizedDataset(ImageFolder("/content/drive/MyDrive/dissertation_exprienments/data/cassavaleafdata/validation", transform=valid_augs))
val_loader = DataLoader(validation_data, batch_size=TEST_BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

# %%
test_data = CustomizedDataset(ImageFolder("/content/drive/MyDrive/dissertation_exprienments/data/cassavaleafdata/test", transform=valid_augs))
test_loader = DataLoader(test_data, batch_size=TEST_BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model = model.to(device)
valid_acc,activationDict = evaluate(model,device,val_loader,hookLayers,hookLayersActivationDict)
# Out:
# Iteration:   0%|          | 0/237 [00:09<?, ?it/s]

# %%
activationDict['bn1'][0].size()
# Out:
# torch.Size([8, 64, 224, 224])

# %% [markdown]
# ## HSIC calculation and plots

# %%
col1,col2,hsicScoreList = getLayerWiseOutputCorrelation(hookLayers,hookLayers,activationDict,activationDict)
# Out:
# Streaming output truncated to the last 5000 lines.
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.6.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.6.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.6.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.6.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.bn2, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.relu2, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.7.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.8.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.bn1, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.relu1, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.9.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.bn1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.relu1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.10.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.bn1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.relu1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.bn2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.relu2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.11.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.12.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.bn1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.relu1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.bn2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.relu2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.13.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.14.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.bn3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.15.relu3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.16.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.bn1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.relu1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.bn3, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.17.relu3, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.bn2, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.relu2, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.18.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.19.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.bn1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.relu1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.20.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.bn2, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.relu2, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.21.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer3.22.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.bn3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.0.relu3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.bn3, HSIC score:0.04878826439380646
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.1.relu3, HSIC score:0.04878826439380646
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.bn3, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:layer4.2.relu3, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:avgpool, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Layer 1:fc, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:bn1, HSIC score:0.13451887667179108
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:relu, HSIC score:0.13451887667179108
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.bn1, HSIC score:0.13637728989124298
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.relu1, HSIC score:0.13637728989124298
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.bn2, HSIC score:0.13733398914337158
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.relu2, HSIC score:0.13733398914337158
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.bn3, HSIC score:0.0621853843331337
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.0.relu3, HSIC score:0.0621853843331337
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.bn1, HSIC score:0.12395334988832474
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.relu1, HSIC score:0.12395334988832474
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.bn2, HSIC score:0.11823667585849762
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.relu2, HSIC score:0.11823667585849762
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.bn3, HSIC score:0.011360273696482182
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.1.relu3, HSIC score:0.011360273696482182
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.2.bn1, HSIC score:0.10228308290243149
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1.2.relu1, HSIC score:0.10228308290243149
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Layer 1:layer1
, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.relu1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.5.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.6.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Layer 1:layer3.7.bn1, HSIC score:nan
# ...
# Layer 1:layer3.0.relu3, HSIC score:0.0605802908539772
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.bn1, HSIC score:0.2302105575799942
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.relu1, HSIC score:0.2302105575799942
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.bn2, HSIC score:0.12652479112148285
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.relu2, HSIC score:0.12652479112148285
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.bn3, HSIC score:0.016800105571746826
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.1.relu3, HSIC score:0.016800105571746826
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.bn1, HSIC score:139003.96875
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.relu1, HSIC score:139003.96875
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.bn2, HSIC score:0.08792635053396225
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.relu2, HSIC score:0.08792635053396225
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.bn3, HSIC score:0.015997735783457756
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.2.relu3, HSIC score:0.015997735783457756
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.bn1, HSIC score:1233796333568.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.relu1, HSIC score:1233796333568.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.bn2, HSIC score:1233813241856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.relu2, HSIC score:1233813241856.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.3.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.bn1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.relu1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.bn3, HSIC score:2.505955156348506e-30
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.4.relu3, HSIC score:2.505955156348506e-30
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.bn1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.relu1, HSIC score:inf
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.5.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.6.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.bn2, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.relu2, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.7.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.8.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.bn1, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.relu1, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.9.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.bn1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.relu1, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.10.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.bn1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.relu1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.bn2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.relu2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.11.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.12.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.bn1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.relu1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.bn2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.relu2, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.13.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.14.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.bn3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.15.relu3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.16.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.bn1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.relu1, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.bn3, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.17.relu3, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.bn2, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.relu2, HSIC score:0.1428571343421936
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.bn3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.18.relu3, HSIC score:0.0
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.19.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.bn1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.relu1, HSIC score:0.10331632196903229
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.bn3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.20.relu3, HSIC score:0.031887754797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.bn2, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.relu2, HSIC score:0.06632652878761292
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.21.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.bn2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.relu2, HSIC score:0.1227678582072258
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.bn3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer3.22.relu3, HSIC score:0.015625
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.bn1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.relu1, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.bn3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.0.relu3, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.bn3, HSIC score:0.04878826439380646
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.1.relu3, HSIC score:0.04878826439380646
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.bn1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.relu1, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.bn2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.relu2, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.bn3, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:layer4.2.relu3, HSIC score:0.08450254797935486
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:avgpool, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan
# Layer 1:fc, HSIC score:nan
# Layer 1:fc, HSIC score:nan
# Cross HSIC score:nan
# Denom:nan

# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.ticker as ticker

# %%
hsicData = {
    'L1' : col1,
    'L2' : col2,
    'hsic':hsicScoreList
}

hsicDataFrame = pd.DataFrame(data=hsicData)
hsicDataFrame = hsicDataFrame.pivot("L1", "L2", "hsic")

# %%
plt.figure(figsize=(12,8))
ax = sns.heatmap(hsicDataFrame.T, cmap='YlGnBu')
plt.xlabel("Layers R101",fontsize='36')
plt.ylabel("Layers R101",fontsize='36')
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xticks(ax.get_xticks()[::4])
ax.set_yticks(ax.get_yticks()[::4])
ax.invert_yaxis()
plt.savefig(LABEL+"_"+TYPE+'.pdf',fmt='pdf',bbox_inches='tight')
